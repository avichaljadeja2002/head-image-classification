# %%
from PIL import Image
import os
person_name = "tammo"
folder_path = "faces/" + person_name
augmented_folder = os.path.join(folder_path, person_name + "_flipped")
os.makedirs(augmented_folder, exist_ok=True)
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    # Skip files with a .bad extension
    if filename.lower().endswith('.bad'):
        print(f"Skipping file with .bad extension: {filename}")
        continue
    try:
        # Open the image file
        with Image.open(file_path) as img:
            # Flip image across x = 0 (horizontal flip)
            flipped_img = img.transpose(Image.FLIP_LEFT_RIGHT)
            # Rename "left" to "right" and vice versa in the filename
            base_name, ext = os.path.splitext(filename)
            if "left" in base_name.lower():
                flipped_base_name = base_name.lower().replace("left", "right")
            elif "right" in base_name.lower():
                flipped_base_name = base_name.lower().replace("right", "left")
            else:
                flipped_base_name = base_name
            # Append unique identifier for flipped image
            flipped_filename = f"{flipped_base_name}_flipped_x0{ext}"
            flipped_img.save(os.path.join(augmented_folder, flipped_filename))
            print(f"Original image saved as {filename}, flipped image saved as {flipped_filename}")
    except IOError:
        print(f"Skipping file {filename}. It is not a valid image.")
# Out:
# Skipping file tammo_flipped. It is not a valid image.
# Original image saved as tammo_left_angry_open.png, flipped image saved as tammo_right_angry_open_flipped_x0.png
# Original image saved as tammo_left_angry_open_2.png, flipped image saved as tammo_right_angry_open_2_flipped_x0.png
# Original image saved as tammo_left_angry_open_4.png, flipped image saved as tammo_right_angry_open_4_flipped_x0.png
# Original image saved as tammo_left_angry_sunglasses.png, flipped image saved as tammo_right_angry_sunglasses_flipped_x0.png
# Original image saved as tammo_left_angry_sunglasses_2.png, flipped image saved as tammo_right_angry_sunglasses_2_flipped_x0.png
# Original image saved as tammo_left_angry_sunglasses_4.png, flipped image saved as tammo_right_angry_sunglasses_4_flipped_x0.png
# Original image saved as tammo_left_happy_open.png, flipped image saved as tammo_right_happy_open_flipped_x0.png
# Original image saved as tammo_left_happy_open_2.png, flipped image saved as tammo_right_happy_open_2_flipped_x0.png
# Original image saved as tammo_left_happy_open_4.png, flipped image saved as tammo_right_happy_open_4_flipped_x0.png
# Original image saved as tammo_left_happy_sunglasses.png, flipped image saved as tammo_right_happy_sunglasses_flipped_x0.png
# Original image saved as tammo_left_happy_sunglasses_2.png, flipped image saved as tammo_right_happy_sunglasses_2_flipped_x0.png
# Original image saved as tammo_left_happy_sunglasses_4.png, flipped image saved as tammo_right_happy_sunglasses_4_flipped_x0.png
# Original image saved as tammo_left_neutral_open.png, flipped image saved as tammo_right_neutral_open_flipped_x0.png
# Original image saved as tammo_left_neutral_open_2.png, flipped image saved as tammo_right_neutral_open_2_flipped_x0.png
# Original image saved as tammo_left_neutral_open_4.png, flipped image saved as tammo_right_neutral_open_4_flipped_x0.png
# Original image saved as tammo_left_neutral_sunglasses.png, flipped image saved as tammo_right_neutral_sunglasses_flipped_x0.png
# Original image saved as tammo_left_neutral_sunglasses_2.png, flipped image saved as tammo_right_neutral_sunglasses_2_flipped_x0.png
# Original image saved as tammo_left_neutral_sunglasses_4.png, flipped image saved as tammo_right_neutral_sunglasses_4_flipped_x0.png
# Original image saved as tammo_left_sad_open.png, flipped image saved as tammo_right_sad_open_flipped_x0.png
# Original image saved as tammo_left_sad_open_2.png, flipped image saved as tammo_right_sad_open_2_flipped_x0.png
# Original image saved as tammo_left_sad_open_4.png, flipped image saved as tammo_right_sad_open_4_flipped_x0.png
# Original image saved as tammo_left_sad_sunglasses.png, flipped image saved as tammo_right_sad_sunglasses_flipped_x0.png
# Original image saved as tammo_left_sad_sunglasses_2.png, flipped image saved as tammo_right_sad_sunglasses_2_flipped_x0.png
# Original image saved as tammo_left_sad_sunglasses_4.png, flipped image saved as tammo_right_sad_sunglasses_4_flipped_x0.png
# Original image saved as tammo_right_angry_open.png, flipped image saved as tammo_left_angry_open_flipped_x0.png
# Original image saved as tammo_right_angry_open_2.png, flipped image saved as tammo_left_angry_open_2_flipped_x0.png
# Original image saved as tammo_right_angry_open_4.png, flipped image saved as tammo_left_angry_open_4_flipped_x0.png
# Original image saved as tammo_right_angry_sunglasses.png, flipped image saved as tammo_left_angry_sunglasses_flipped_x0.png
# Original image saved as tammo_right_angry_sunglasses_2.png, flipped image saved as tammo_left_angry_sunglasses_2_flipped_x0.png
# Original image saved as tammo_right_angry_sunglasses_4.png, flipped image saved as tammo_left_angry_sunglasses_4_flipped_x0.png
# Skipping file with .bad extension: tammo_right_happy_open.bad
# Original image saved as tammo_right_happy_sunglasses.png, flipped image saved as tammo_left_happy_sunglasses_flipped_x0.png
# Original image saved as tammo_right_happy_sunglasses_2.png, flipped image saved as tammo_left_happy_sunglasses_2_flipped_x0.png
# Original image saved as tammo_right_happy_sunglasses_4.png, flipped image saved as tammo_left_happy_sunglasses_4_flipped_x0.png
# Original image saved as tammo_right_neutral_open.png, flipped image saved as tammo_left_neutral_open_flipped_x0.png
# Original image saved as tammo_right_neutral_open_2.png, flipped image saved as tammo_left_neutral_open_2_flipped_x0.png
# Original image saved as tammo_right_neutral_open_4.png, flipped image saved as tammo_left_neutral_open_4_flipped_x0.png
# Original image saved as tammo_right_neutral_sunglasses.png, flipped image saved as tammo_left_neutral_sunglasses_flipped_x0.png
# Original image saved as tammo_right_neutral_sunglasses_2.png, flipped image saved as tammo_left_neutral_sunglasses_2_flipped_x0.png
# Original image saved as tammo_right_neutral_sunglasses_4.png, flipped image saved as tammo_left_neutral_sunglasses_4_flipped_x0.png
# Skipping file with .bad extension: tammo_right_sad_open.bad
# Original image saved as tammo_right_sad_sunglasses.png, flipped image saved as tammo_left_sad_sunglasses_flipped_x0.png
# Original image saved as tammo_right_sad_sunglasses_2.png, flipped image saved as tammo_left_sad_sunglasses_2_flipped_x0.png
# Original image saved as tammo_right_sad_sunglasses_4.png, flipped image saved as tammo_left_sad_sunglasses_4_flipped_x0.png
# Original image saved as tammo_straight_angry_open.png, flipped image saved as tammo_straight_angry_open_flipped_x0.png
# Original image saved as tammo_straight_angry_open_2.png, flipped image saved as tammo_straight_angry_open_2_flipped_x0.png
# Original image saved as tammo_straight_angry_open_4.png, flipped image saved as tammo_straight_angry_open_4_flipped_x0.png
# Original image saved as tammo_straight_angry_sunglasses.png, flipped image saved as tammo_straight_angry_sunglasses_flipped_x0.png
# Original image saved as tammo_straight_angry_sunglasses_2.png, flipped image saved as tammo_straight_angry_sunglasses_2_flipped_x0.png
# Original image saved as tammo_straight_angry_sunglasses_4.png, flipped image saved as tammo_straight_angry_sunglasses_4_flipped_x0.png
# Original image saved as tammo_straight_happy_open.png, flipped image saved as tammo_straight_happy_open_flipped_x0.png
# Original image saved as tammo_straight_happy_open_2.png, flipped image saved as tammo_straight_happy_open_2_flipped_x0.png
# Original image saved as tammo_straight_happy_open_4.png, flipped image saved as tammo_straight_happy_open_4_flipped_x0.png
# Original image saved as tammo_straight_happy_sunglasses.png, flipped image saved as tammo_straight_happy_sunglasses_flipped_x0.png
# Original image saved as tammo_straight_happy_sunglasses_2.png, flipped image saved as tammo_straight_happy_sunglasses_2_flipped_x0.png
# Original image saved as tammo_straight_happy_sunglasses_4.png, flipped image saved as tammo_straight_happy_sunglasses_4_flipped_x0.png
# Original image saved as tammo_straight_neutral_open.png, flipped image saved as tammo_straight_neutral_open_flipped_x0.png
# Original image saved as tammo_straight_neutral_open_2.png, flipped image saved as tammo_straight_neutral_open_2_flipped_x0.png
# Original image saved as tammo_straight_neutral_open_4.png, flipped image saved as tammo_straight_neutral_open_4_flipped_x0.png
# Original image saved as tammo_straight_neutral_sunglasses.png, flipped image saved as tammo_straight_neutral_sunglasses_flipped_x0.png
# Original image saved as tammo_straight_neutral_sunglasses_2.png, flipped image saved as tammo_straight_neutral_sunglasses_2_flipped_x0.png
# Original image saved as tammo_straight_neutral_sunglasses_4.png, flipped image saved as tammo_straight_neutral_sunglasses_4_flipped_x0.png
# Original image saved as tammo_straight_sad_open.png, flipped image saved as tammo_straight_sad_open_flipped_x0.png
# Original image saved as tammo_straight_sad_open_2.png, flipped image saved as tammo_straight_sad_open_2_flipped_x0.png
# Original image saved as tammo_straight_sad_open_4.png, flipped image saved as tammo_straight_sad_open_4_flipped_x0.png
# Original image saved as tammo_straight_sad_sunglasses.png, flipped image saved as tammo_straight_sad_sunglasses_flipped_x0.png
# Original image saved as tammo_straight_sad_sunglasses_2.png, flipped image saved as tammo_straight_sad_sunglasses_2_flipped_x0.png
# Original image saved as tammo_straight_sad_sunglasses_4.png, flipped image saved as tammo_straight_sad_sunglasses_4_flipped_x0.png
# Original image saved as tammo_up_angry_open.png, flipped image saved as tammo_up_angry_open_flipped_x0.png
# Original image saved as tammo_up_angry_open_2.png, flipped image saved as tammo_up_angry_open_2_flipped_x0.png
# Original image saved as tammo_up_angry_open_4.png, flipped image saved as tammo_up_angry_open_4_flipped_x0.png
# Original image saved as tammo_up_angry_sunglasses.png, flipped image saved as tammo_up_angry_sunglasses_flipped_x0.png
# Original image saved as tammo_up_angry_sunglasses_2.png, flipped image saved as tammo_up_angry_sunglasses_2_flipped_x0.png
# Original image saved as tammo_up_angry_sunglasses_4.png, flipped image saved as tammo_up_angry_sunglasses_4_flipped_x0.png
# Original image saved as tammo_up_happy_open.png, flipped image saved as tammo_up_happy_open_flipped_x0.png
# Original image saved as tammo_up_happy_open_2.png, flipped image saved as tammo_up_happy_open_2_flipped_x0.png
# Original image saved as tammo_up_happy_open_4.png, flipped image saved as tammo_up_happy_open_4_flipped_x0.png
# Original image saved as tammo_up_happy_sunglasses.png, flipped image saved as tammo_up_happy_sunglasses_flipped_x0.png
# Original image saved as tammo_up_happy_sunglasses_2.png, flipped image saved as tammo_up_happy_sunglasses_2_flipped_x0.png
# Original image saved as tammo_up_happy_sunglasses_4.png, flipped image saved as tammo_up_happy_sunglasses_4_flipped_x0.png
# Original image saved as tammo_up_neutral_open.png, flipped image saved as tammo_up_neutral_open_flipped_x0.png
# Original image saved as tammo_up_neutral_open_2.png, flipped image saved as tammo_up_neutral_open_2_flipped_x0.png
# Original image saved as tammo_up_neutral_open_4.png, flipped image saved as tammo_up_neutral_open_4_flipped_x0.png
# Original image saved as tammo_up_neutral_sunglasses.png, flipped image saved as tammo_up_neutral_sunglasses_flipped_x0.png
# Original image saved as tammo_up_neutral_sunglasses_2.png, flipped image saved as tammo_up_neutral_sunglasses_2_flipped_x0.png
# Original image saved as tammo_up_neutral_sunglasses_4.png, flipped image saved as tammo_up_neutral_sunglasses_4_flipped_x0.png
# Original image saved as tammo_up_sad_open.png, flipped image saved as tammo_up_sad_open_flipped_x0.png
# Original image saved as tammo_up_sad_open_2.png, flipped image saved as tammo_up_sad_open_2_flipped_x0.png
# Original image saved as tammo_up_sad_open_4.png, flipped image saved as tammo_up_sad_open_4_flipped_x0.png
# Original image saved as tammo_up_sad_sunglasses.png, flipped image saved as tammo_up_sad_sunglasses_flipped_x0.png
# Original image saved as tammo_up_sad_sunglasses_2.png, flipped image saved as tammo_up_sad_sunglasses_2_flipped_x0.png
# Original image saved as tammo_up_sad_sunglasses_4.png, flipped image saved as tammo_up_sad_sunglasses_4_flipped_x0.png
